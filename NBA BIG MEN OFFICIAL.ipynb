# %%
import numpy as np
import pandas as pd
import os 
import warnings
import seaborn as sns
warnings.filterwarnings("ignore")

# %%
os.getcwd
# Out:
# <function posix.getcwd()>

# %%
df = pd.read_csv("/Users/krisjones/Desktop/Python/all_seasons.csv")

# %%
df
df2 = df

# %%
del df2["Unnamed: 0"]

# %%
df2
# Out:
#                player_name team_abbreviation   age  player_height  \
# 0            Travis Knight               LAL  22.0         213.36
# 1                Matt Fish               MIA  27.0         210.82
# 2             Matt Bullard               HOU  30.0         208.28
# 3             Marty Conlon               BOS  29.0         210.82
# 4          Martin Muursepp               DAL  22.0         205.74
# ...                    ...               ...   ...            ...
# 11695  Matthew Dellavedova               CLE  30.0         190.50
# 11696     Maurice Harkless               SAC  28.0         200.66
# 11697            Max Strus               MIA  25.0         195.58
# 11698    Marcus Morris Sr.               LAC  31.0         203.20
# 11699         Aaron Gordon               DEN  25.0         203.20
#
#        player_weight                          college    country draft_year  \
# 0         106.594120                      Connecticut        USA       1996
# 1         106.594120        North Carolina-Wilmington        USA       1992
# 2         106.594120                             Iowa        USA  Undrafted
# 3         111.130040                       Providence        USA  Undrafted
# 4         106.594120                             None        USA       1996
# ...              ...                              ...        ...        ...
# 11695      90.718400  St.Mary's College of California  Australia  Undrafted
# 11696      99.790240                       St. John's        USA       2012
# 11697      97.522280                           DePaul        USA  Undrafted
# 11698      98.883056                           Kansas        USA       2011
# 11699     106.594120                          Arizona        USA       2014
#
#       draft_round draft_number  ...   pts  reb  ast  net_rating  oreb_pct  \
# 0               1           29  ...   4.8  4.5  0.5         6.2     0.127
# 1               2           50  ...   0.3  0.8  0.0       -15.1     0.143
# 2       Undrafted    Undrafted  ...   4.5  1.6  0.9         0.9     0.016
# 3       Undrafted    Undrafted  ...   7.8  4.4  1.4        -9.0     0.083
# 4               1           25  ...   3.7  1.6  0.5       -14.5     0.109
# ...           ...          ...  ...   ...  ...  ...         ...       ...
# 11695   Undrafted    Undrafted  ...   2.8  1.8  4.5        -3.1     0.029
# 11696           1           15  ...   5.2  2.4  1.2        -2.9     0.017
# 11697   Undrafted    Undrafted  ...   6.1  1.1  0.6        -4.2     0.011
# 11698           1           14  ...  13.4  4.1  1.0         4.2     0.025
# 11699           1            4  ...  12.4  5.7  3.2         2.1     0.055
#
#        dreb_pct  usg_pct  ts_pct  ast_pct   season
# 0         0.182    0.142   0.536    0.052  1996-97
# 1         0.267    0.265   0.333    0.000  1996-97
# 2         0.115    0.151   0.535    0.099  1996-97
# 3         0.152    0.167   0.542    0.101  1996-97
# 4         0.118    0.233   0.482    0.114  1996-97
# ...         ...      ...     ...      ...      ...
# 11695     0.085    0.125   0.312    0.337  2020-21
# 11696     0.097    0.114   0.527    0.071  2020-21
# 11697     0.073    0.179   0.597    0.074  2020-21
# 11698     0.133    0.194   0.614    0.056  2020-21
# 11699     0.150    0.204   0.547    0.165  2020-21
#
# [11700 rows x 21 columns]

# %%
#Convert Height to In 

for i in range (len(df)):
    df.iat[i,3] = df.iat[i,3] / 2.54
    round(df.iat[i,3])
# Out:
#                player_name team_abbreviation   age  player_height  \
# 0            Travis Knight               LAL  22.0           84.0
# 1                Matt Fish               MIA  27.0           83.0
# 2             Matt Bullard               HOU  30.0           82.0
# 3             Marty Conlon               BOS  29.0           83.0
# 4          Martin Muursepp               DAL  22.0           81.0
# ...                    ...               ...   ...            ...
# 11695  Matthew Dellavedova               CLE  30.0           75.0
# 11696     Maurice Harkless               SAC  28.0           79.0
# 11697            Max Strus               MIA  25.0           77.0
# 11698    Marcus Morris Sr.               LAC  31.0           80.0
# 11699         Aaron Gordon               DEN  25.0           80.0
#
#        player_weight                          college    country draft_year  \
# 0         106.594120                      Connecticut        USA       1996
# 1         106.594120        North Carolina-Wilmington        USA       1992
# 2         106.594120                             Iowa        USA  Undrafted
# 3         111.130040                       Providence        USA  Undrafted
# 4         106.594120                             None        USA       1996
# ...              ...                              ...        ...        ...
# 11695      90.718400  St.Mary's College of California  Australia  Undrafted
# 11696      99.790240                       St. John's        USA       2012
# 11697      97.522280                           DePaul        USA  Undrafted
# 11698      98.883056                           Kansas        USA       2011
# 11699     106.594120                          Arizona        USA       2014
#
#       draft_round draft_number  ...   pts  reb  ast  net_rating  oreb_pct  \
# 0               1           29  ...   4.8  4.5  0.5         6.2     0.127
# 1               2           50  ...   0.3  0.8  0.0       -15.1     0.143
# 2       Undrafted    Undrafted  ...   4.5  1.6  0.9         0.9     0.016
# 3       Undrafted    Undrafted  ...   7.8  4.4  1.4        -9.0     0.083
# 4               1           25  ...   3.7  1.6  0.5       -14.5     0.109
# ...           ...          ...  ...   ...  ...  ...         ...       ...
# 11695   Undrafted    Undrafted  ...   2.8  1.8  4.5        -3.1     0.029
# 11696           1           15  ...   5.2  2.4  1.2        -2.9     0.017
# 11697   Undrafted    Undrafted  ...   6.1  1.1  0.6        -4.2     0.011
# 11698           1           14  ...  13.4  4.1  1.0         4.2     0.025
# 11699           1            4  ...  12.4  5.7  3.2         2.1     0.055
#
#        dreb_pct  usg_pct  ts_pct  ast_pct   season
# 0         0.182    0.142   0.536    0.052  1996-97
# 1         0.267    0.265   0.333    0.000  1996-97
# 2         0.115    0.151   0.535    0.099  1996-97
# 3         0.152    0.167   0.542    0.101  1996-97
# 4         0.118    0.233   0.482    0.114  1996-97
# ...         ...      ...     ...      ...      ...
# 11695     0.085    0.125   0.312    0.337  2020-21
# 11696     0.097    0.114   0.527    0.071  2020-21
# 11697     0.073    0.179   0.597    0.074  2020-21
# 11698     0.133    0.194   0.614    0.056  2020-21
# 11699     0.150    0.204   0.547    0.165  2020-21
#
# [11700 rows x 21 columns]

# %%
#Convert Weight to Lbs
for i in range (len(df)):
    df.iat[i,4] = df.iat[i,4] * 2.205
    round(df.iat[i,4])
df
# Out:
#                player_name team_abbreviation   age  player_height  \
# 0            Travis Knight               LAL  22.0           84.0
# 1                Matt Fish               MIA  27.0           83.0
# 2             Matt Bullard               HOU  30.0           82.0
# 3             Marty Conlon               BOS  29.0           83.0
# 4          Martin Muursepp               DAL  22.0           81.0
# ...                    ...               ...   ...            ...
# 11695  Matthew Dellavedova               CLE  30.0           75.0
# 11696     Maurice Harkless               SAC  28.0           79.0
# 11697            Max Strus               MIA  25.0           77.0
# 11698    Marcus Morris Sr.               LAC  31.0           80.0
# 11699         Aaron Gordon               DEN  25.0           80.0
#
#        player_weight                          college    country draft_year  \
# 0         235.040035                      Connecticut        USA       1996
# 1         235.040035        North Carolina-Wilmington        USA       1992
# 2         235.040035                             Iowa        USA  Undrafted
# 3         245.041738                       Providence        USA  Undrafted
# 4         235.040035                             None        USA       1996
# ...              ...                              ...        ...        ...
# 11695     200.034072  St.Mary's College of California  Australia  Undrafted
# 11696     220.037479                       St. John's        USA       2012
# 11697     215.036627                           DePaul        USA  Undrafted
# 11698     218.037138                           Kansas        USA       2011
# 11699     235.040035                          Arizona        USA       2014
#
#       draft_round draft_number  ...   pts  reb  ast  net_rating  oreb_pct  \
# 0               1           29  ...   4.8  4.5  0.5         6.2     0.127
# 1               2           50  ...   0.3  0.8  0.0       -15.1     0.143
# 2       Undrafted    Undrafted  ...   4.5  1.6  0.9         0.9     0.016
# 3       Undrafted    Undrafted  ...   7.8  4.4  1.4        -9.0     0.083
# 4               1           25  ...   3.7  1.6  0.5       -14.5     0.109
# ...           ...          ...  ...   ...  ...  ...         ...       ...
# 11695   Undrafted    Undrafted  ...   2.8  1.8  4.5        -3.1     0.029
# 11696           1           15  ...   5.2  2.4  1.2        -2.9     0.017
# 11697   Undrafted    Undrafted  ...   6.1  1.1  0.6        -4.2     0.011
# 11698           1           14  ...  13.4  4.1  1.0         4.2     0.025
# 11699           1            4  ...  12.4  5.7  3.2         2.1     0.055
#
#        dreb_pct  usg_pct  ts_pct  ast_pct   season
# 0         0.182    0.142   0.536    0.052  1996-97
# 1         0.267    0.265   0.333    0.000  1996-97
# 2         0.115    0.151   0.535    0.099  1996-97
# 3         0.152    0.167   0.542    0.101  1996-97
# 4         0.118    0.233   0.482    0.114  1996-97
# ...         ...      ...     ...      ...      ...
# 11695     0.085    0.125   0.312    0.337  2020-21
# 11696     0.097    0.114   0.527    0.071  2020-21
# 11697     0.073    0.179   0.597    0.074  2020-21
# 11698     0.133    0.194   0.614    0.056  2020-21
# 11699     0.150    0.204   0.547    0.165  2020-21
#
# [11700 rows x 21 columns]

# %%
#Round Weight
for i in range (len(df)):
    df.iat[i,4] = round(df.iat[i,4])

# %%
#Since there are no positions in this data set, I will use player height to identify the "big men" in the NBA. 
#According to draft express, the average PF height in the NBA is 6'9(81 inches) with shoes. 

#Create filter for 81 inches

H = df.player_height >= 81.0

# %%
#Analysis is for players drafted in the first round of the NBA Draft
#Create Filter for Round 1

Fr = df.draft_round == "1"

# %%
#Create A Filter for Draft Year. Analyzing Players Drafted from 1996 to present 

df2 = df[H]

# %%
df2 = df[Fr]

# %%
#Filterd for Players Above 81 Inches and Drafted In First Round 
df2
# Out:
#              player_name team_abbreviation   age  player_height  \
# 0          Travis Knight               LAL  22.0           84.0
# 4        Martin Muursepp               DAL  22.0           81.0
# 9           Mark Jackson               IND  32.0           75.0
# 12           Mark Bryant               PHX  32.0           81.0
# 15          Marcus Camby               TOR  23.0           83.0
# ...                  ...               ...   ...            ...
# 11692      Mason Plumlee               DET  31.0           83.0
# 11693   Matisse Thybulle               PHI  24.0           77.0
# 11696   Maurice Harkless               SAC  28.0           79.0
# 11698  Marcus Morris Sr.               LAC  31.0           80.0
# 11699       Aaron Gordon               DEN  25.0           80.0
#
#        player_weight          college country draft_year draft_round  \
# 0              235.0      Connecticut     USA       1996           1
# 4              235.0             None     USA       1996           1
# 9              185.0  St. John's (NY)     USA       1987           1
# 12             245.0       Seton Hall     USA       1988           1
# 15             220.0    Massachusetts     USA       1996           1
# ...              ...              ...     ...        ...         ...
# 11692          254.0             Duke     USA       2013           1
# 11693          201.0       Washington     USA       2019           1
# 11696          220.0       St. John's     USA       2012           1
# 11698          218.0           Kansas     USA       2011           1
# 11699          235.0          Arizona     USA       2014           1
#
#       draft_number  ...   pts  reb   ast  net_rating  oreb_pct  dreb_pct  \
# 0               29  ...   4.8  4.5   0.5         6.2     0.127     0.182
# 4               25  ...   3.7  1.6   0.5       -14.5     0.109     0.118
# 9               18  ...   9.9  4.8  11.4        -2.0     0.035     0.116
# 12              21  ...   9.3  5.2   1.1         3.3     0.084     0.186
# 15               2  ...  14.8  6.3   1.5        -1.5     0.079     0.165
# ...            ...  ...   ...  ...   ...         ...       ...       ...
# 11692           22  ...  10.4  9.3   3.6        -4.9     0.095     0.264
# 11693           20  ...   3.9  1.9   1.0         4.6     0.023     0.070
# 11696           15  ...   5.2  2.4   1.2        -2.9     0.017     0.097
# 11698           14  ...  13.4  4.1   1.0         4.2     0.025     0.133
# 11699            4  ...  12.4  5.7   3.2         2.1     0.055     0.150
#
#        usg_pct  ts_pct  ast_pct   season
# 0        0.142   0.536    0.052  1996-97
# 4        0.233   0.482    0.114  1996-97
# 9        0.155   0.525    0.464  1996-97
# 12       0.167   0.589    0.072  1996-97
# 15       0.241   0.523    0.092  1996-97
# ...        ...     ...      ...      ...
# 11692    0.163   0.638    0.205  2020-21
# 11693    0.090   0.508    0.064  2020-21
# 11696    0.114   0.527    0.071  2020-21
# 11698    0.194   0.614    0.056  2020-21
# 11699    0.204   0.547    0.165  2020-21
#
# [6792 rows x 21 columns]

# %%
#Create Filter for Players Drafted From 1996 to Present
DY = list(df.draft_year)
DY = np.unique(DY)
np.sort(DY)
# Out:
# array(['1963', '1976', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', 'Undrafted'], dtype='<U9')

# %%
D = df.draft_year == '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', \
'2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015','2016', '2017', '2018', '2019', '2020'

# %%
#Draft Year Filter 
df2[df2.draft_year.isin(D)]
# Out:
#              player_name team_abbreviation   age  player_height  \
# 441              Ed Gray               ATL  22.0           75.0
# 482       Derek Anderson               CLE  23.0           77.0
# 504        Jacque Vaughn               UTA  23.0           73.0
# 553      Austin Croshere               IND  23.0           81.0
# 569        Bobby Jackson               DEN  25.0           73.0
# ...                  ...               ...   ...            ...
# 11692      Mason Plumlee               DET  31.0           83.0
# 11693   Matisse Thybulle               PHI  24.0           77.0
# 11696   Maurice Harkless               SAC  28.0           79.0
# 11698  Marcus Morris Sr.               LAC  31.0           80.0
# 11699       Aaron Gordon               DEN  25.0           80.0
#
#        player_weight     college country draft_year draft_round draft_number  \
# 441            210.0  California     USA       1997           1           22
# 482            195.0    Kentucky     USA       1997           1           13
# 504            190.0      Kansas     USA       1997           1           27
# 553            235.0  Providence     USA       1997           1           12
# 569            185.0   Minnesota     USA       1997           1           23
# ...              ...         ...     ...        ...         ...          ...
# 11692          254.0        Duke     USA       2013           1           22
# 11693          201.0  Washington     USA       2019           1           20
# 11696          220.0  St. John's     USA       2012           1           15
# 11698          218.0      Kansas     USA       2011           1           14
# 11699          235.0     Arizona     USA       2014           1            4
#
#        ...   pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# 441    ...   7.6  1.5  1.1        -8.3     0.023     0.090    0.248   0.492
# 482    ...  11.7  2.8  3.4         3.9     0.038     0.091    0.215   0.531
# 504    ...   3.1  0.8  1.9         2.9     0.012     0.086    0.218   0.457
# 553    ...   2.9  1.7  0.3        -3.1     0.047     0.169    0.194   0.412
# 569    ...  11.6  4.4  4.7       -12.5     0.043     0.128    0.232   0.453
# ...    ...   ...  ...  ...         ...       ...       ...      ...     ...
# 11692  ...  10.4  9.3  3.6        -4.9     0.095     0.264    0.163   0.638
# 11693  ...   3.9  1.9  1.0         4.6     0.023     0.070    0.090   0.508
# 11696  ...   5.2  2.4  1.2        -2.9     0.017     0.097    0.114   0.527
# 11698  ...  13.4  4.1  1.0         4.2     0.025     0.133    0.194   0.614
# 11699  ...  12.4  5.7  3.2         2.1     0.055     0.150    0.204   0.547
#
#        ast_pct   season
# 441      0.132  1997-98
# 482      0.219  1997-98
# 504      0.315  1997-98
# 553      0.052  1997-98
# 569      0.288  1997-98
# ...        ...      ...
# 11692    0.205  2020-21
# 11693    0.064  2020-21
# 11696    0.071  2020-21
# 11698    0.056  2020-21
# 11699    0.165  2020-21
#
# [5070 rows x 21 columns]

# %%
df2 = df2[df2.draft_year.isin(D)]
df2
# Out:
#              player_name team_abbreviation   age  player_height  \
# 441              Ed Gray               ATL  22.0           75.0
# 482       Derek Anderson               CLE  23.0           77.0
# 504        Jacque Vaughn               UTA  23.0           73.0
# 553      Austin Croshere               IND  23.0           81.0
# 569        Bobby Jackson               DEN  25.0           73.0
# ...                  ...               ...   ...            ...
# 11692      Mason Plumlee               DET  31.0           83.0
# 11693   Matisse Thybulle               PHI  24.0           77.0
# 11696   Maurice Harkless               SAC  28.0           79.0
# 11698  Marcus Morris Sr.               LAC  31.0           80.0
# 11699       Aaron Gordon               DEN  25.0           80.0
#
#        player_weight     college country draft_year draft_round draft_number  \
# 441            210.0  California     USA       1997           1           22
# 482            195.0    Kentucky     USA       1997           1           13
# 504            190.0      Kansas     USA       1997           1           27
# 553            235.0  Providence     USA       1997           1           12
# 569            185.0   Minnesota     USA       1997           1           23
# ...              ...         ...     ...        ...         ...          ...
# 11692          254.0        Duke     USA       2013           1           22
# 11693          201.0  Washington     USA       2019           1           20
# 11696          220.0  St. John's     USA       2012           1           15
# 11698          218.0      Kansas     USA       2011           1           14
# 11699          235.0     Arizona     USA       2014           1            4
#
#        ...   pts  reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# 441    ...   7.6  1.5  1.1        -8.3     0.023     0.090    0.248   0.492
# 482    ...  11.7  2.8  3.4         3.9     0.038     0.091    0.215   0.531
# 504    ...   3.1  0.8  1.9         2.9     0.012     0.086    0.218   0.457
# 553    ...   2.9  1.7  0.3        -3.1     0.047     0.169    0.194   0.412
# 569    ...  11.6  4.4  4.7       -12.5     0.043     0.128    0.232   0.453
# ...    ...   ...  ...  ...         ...       ...       ...      ...     ...
# 11692  ...  10.4  9.3  3.6        -4.9     0.095     0.264    0.163   0.638
# 11693  ...   3.9  1.9  1.0         4.6     0.023     0.070    0.090   0.508
# 11696  ...   5.2  2.4  1.2        -2.9     0.017     0.097    0.114   0.527
# 11698  ...  13.4  4.1  1.0         4.2     0.025     0.133    0.194   0.614
# 11699  ...  12.4  5.7  3.2         2.1     0.055     0.150    0.204   0.547
#
#        ast_pct   season
# 441      0.132  1997-98
# 482      0.219  1997-98
# 504      0.315  1997-98
# 553      0.052  1997-98
# 569      0.288  1997-98
# ...        ...      ...
# 11692    0.205  2020-21
# 11693    0.064  2020-21
# 11696    0.071  2020-21
# 11698    0.056  2020-21
# 11699    0.165  2020-21
#
# [5070 rows x 21 columns]

# %%
df2 = df2[H]

# %%
df2
# Out:
#              player_name team_abbreviation   age  player_height  \
# 553      Austin Croshere               IND  23.0           81.0
# 582         Adonal Foyle               GSW  23.0           82.0
# 657         Chris Anstey               DAL  23.0           84.0
# 687         Scot Pollard               DET  23.0           83.0
# 751           Tim Duncan               SAS  22.0           84.0
# ...                  ...               ...   ...            ...
# 11682       LeBron James               LAL  36.0           81.0
# 11686    Markieff Morris               LAL  31.0           81.0
# 11689    Marquese Chriss               GSW  23.0           81.0
# 11690  Marvin Bagley III               SAC  22.0           83.0
# 11692      Mason Plumlee               DET  31.0           83.0
#
#        player_weight      college                   country draft_year  \
# 553            235.0   Providence                       USA       1997
# 582            250.0      Colgate  St. Vincent & Grenadines       1997
# 657            249.0         None                       USA       1997
# 687            265.0       Kansas                       USA       1997
# 751            248.0  Wake Forest         US Virgin Islands       1997
# ...              ...          ...                       ...        ...
# 11682          250.0         None                       USA       2003
# 11686          245.0       Kansas                       USA       2011
# 11689          240.0   Washington                       USA       2016
# 11690          235.0         Duke                       USA       2018
# 11692          254.0         Duke                       USA       2013
#
#       draft_round draft_number  ...   pts   reb  ast  net_rating  oreb_pct  \
# 553             1           12  ...   2.9   1.7  0.3        -3.1     0.047
# 582             1            8  ...   3.0   3.3  0.3       -11.8     0.112
# 657             1           18  ...   5.9   3.8  0.9        -9.8     0.082
# 687             1           19  ...   2.7   2.2  0.3         0.8     0.133
# 751             1            1  ...  21.1  11.9  2.7         8.0     0.108
# ...           ...          ...  ...   ...   ...  ...         ...       ...
# 11682           1            1  ...  25.0   7.7  7.8         9.2     0.020
# 11686           1           13  ...   6.7   4.4  1.2         0.8     0.040
# 11689           1            8  ...   6.5   6.5  1.0       -40.3     0.075
# 11690           1            2  ...  14.1   7.4  1.0        -3.7     0.092
# 11692           1           22  ...  10.4   9.3  3.6        -4.9     0.095
#
#        dreb_pct  usg_pct  ts_pct  ast_pct   season
# 553       0.169    0.194   0.412    0.052  1997-98
# 582       0.182    0.162   0.418    0.037  1997-98
# 657       0.174    0.201   0.455    0.094  1997-98
# 687       0.150    0.136   0.555    0.050  1997-98
# 751       0.238    0.262   0.577    0.131  1997-98
# ...         ...      ...     ...      ...      ...
# 11682     0.202    0.310   0.602    0.394  2020-21
# 11686     0.176    0.160   0.509    0.088  2020-21
# 11689     0.385    0.250   0.412    0.200  2020-21
# 11690     0.188    0.229   0.554    0.057  2020-21
# 11692     0.264    0.163   0.638    0.205  2020-21
#
# [2206 rows x 21 columns]

# %%
df2 = df2[Fr]

# %%
df2
# Out:
#              player_name team_abbreviation   age  player_height  \
# 553      Austin Croshere               IND  23.0           81.0
# 582         Adonal Foyle               GSW  23.0           82.0
# 657         Chris Anstey               DAL  23.0           84.0
# 687         Scot Pollard               DET  23.0           83.0
# 751           Tim Duncan               SAS  22.0           84.0
# ...                  ...               ...   ...            ...
# 11682       LeBron James               LAL  36.0           81.0
# 11686    Markieff Morris               LAL  31.0           81.0
# 11689    Marquese Chriss               GSW  23.0           81.0
# 11690  Marvin Bagley III               SAC  22.0           83.0
# 11692      Mason Plumlee               DET  31.0           83.0
#
#        player_weight      college                   country draft_year  \
# 553            235.0   Providence                       USA       1997
# 582            250.0      Colgate  St. Vincent & Grenadines       1997
# 657            249.0         None                       USA       1997
# 687            265.0       Kansas                       USA       1997
# 751            248.0  Wake Forest         US Virgin Islands       1997
# ...              ...          ...                       ...        ...
# 11682          250.0         None                       USA       2003
# 11686          245.0       Kansas                       USA       2011
# 11689          240.0   Washington                       USA       2016
# 11690          235.0         Duke                       USA       2018
# 11692          254.0         Duke                       USA       2013
#
#       draft_round draft_number  ...   pts   reb  ast  net_rating  oreb_pct  \
# 553             1           12  ...   2.9   1.7  0.3        -3.1     0.047
# 582             1            8  ...   3.0   3.3  0.3       -11.8     0.112
# 657             1           18  ...   5.9   3.8  0.9        -9.8     0.082
# 687             1           19  ...   2.7   2.2  0.3         0.8     0.133
# 751             1            1  ...  21.1  11.9  2.7         8.0     0.108
# ...           ...          ...  ...   ...   ...  ...         ...       ...
# 11682           1            1  ...  25.0   7.7  7.8         9.2     0.020
# 11686           1           13  ...   6.7   4.4  1.2         0.8     0.040
# 11689           1            8  ...   6.5   6.5  1.0       -40.3     0.075
# 11690           1            2  ...  14.1   7.4  1.0        -3.7     0.092
# 11692           1           22  ...  10.4   9.3  3.6        -4.9     0.095
#
#        dreb_pct  usg_pct  ts_pct  ast_pct   season
# 553       0.169    0.194   0.412    0.052  1997-98
# 582       0.182    0.162   0.418    0.037  1997-98
# 657       0.174    0.201   0.455    0.094  1997-98
# 687       0.150    0.136   0.555    0.050  1997-98
# 751       0.238    0.262   0.577    0.131  1997-98
# ...         ...      ...     ...      ...      ...
# 11682     0.202    0.310   0.602    0.394  2020-21
# 11686     0.176    0.160   0.509    0.088  2020-21
# 11689     0.385    0.250   0.412    0.200  2020-21
# 11690     0.188    0.229   0.554    0.057  2020-21
# 11692     0.264    0.163   0.638    0.205  2020-21
#
# [2206 rows x 21 columns]

# %%
Pname = list(df2.player_name)
list.sort(Pname)
# Out:
# ['Aaron Gordon',
#  'Aaron Gordon',
#  'Aaron Gordon',
#  'Aaron Gordon',
#  'Aaron Gordon',
#  'Adonal Foyle',
#  'Adonal Foyle',
#  'Adonal Foyle',
#  'Adonal Foyle',
#  'Adonal Foyle',
#  'Adonal Foyle',
#  'Adonal Foyle',
#  'Adonal Foyle',
#  'Adonal Foyle',
#  'Adonal Foyle',
#  'Adonal Foyle',
#  'Adonal Foyle',
#  'Adreian Payne',
#  'Adreian Payne',
#  'Adreian Payne',
#  'Adreian Payne',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Harrington',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Horford',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al Jefferson',
#  'Al-Farouq Aminu',
#  'Al-Farouq Aminu',
#  'Al-Farouq Aminu',
#  'Al-Farouq Aminu',
#  'Al-Farouq Aminu',
#  'Al-Farouq Aminu',
#  'Al-Farouq Aminu',
#  'Al-Farouq Aminu',
#  'Al-Farouq Aminu',
#  'Aleksandar Radojevic',
#  'Aleksandar Radojevic',
#  'Aleksej Pokusevski',
#  'Alex Len',
#  'Alex Len',
#  'Alex Len',
#  'Alex Len',
#  'Alex Len',
#  'Alex Len',
#  'Alex Len',
#  'Alex Len',
#  'Alexis Ajinca',
#  'Alexis Ajinca',
#  'Alexis Ajinca',
#  'Alexis Ajinca',
#  'Alexis Ajinca',
#  'Alexis Ajinca',
#  'Alexis Ajinca',
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  "Amar'e Stoudemire",
#  'Andre Drummond',
#  'Andre Drummond',
#  'Andre Drummond',
#  'Andre Drummond',
#  'Andre Drummond',
#  'Andre Drummond',
#  'Andre Drummond',
#  'Andre Drummond',
#  'Andre Drummond',
#  'Andrea Bargnani',
#  'Andrea Bargnani',
#  'Andrea Bargnani',
#  'Andrea Bargnani',
#  'Andrea Bargnani',
#  'Andrea Bargnani',
#  'Andrea Bargnani',
#  'Andrea Bargnani',
#  'Andrea Bargnani',
#  'Andrea Bargnani',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrei Kirilenko',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bogut',
#  'Andrew Bynum',
#  'Andrew Bynum',
#  'Andrew Bynum',
#  'Andrew Bynum',
#  'Andrew Bynum',
#  'Andrew Bynum',
#  'Andrew Bynum',
#  'Andrew Bynum',
#  'Andrew Nicholson',
#  'Andrew Nicholson',
#  'Andrew Nicholson',
#  'Andrew Nicholson',
#  'Andrew Nicholson',
#  'Andris Biedrins',
#  'Andris Biedrins',
#  'Andris Biedrins',
#  'Andris Biedrins',
#  'Andris Biedrins',
#  'Andris Biedrins',
#  'Andris Biedrins',
#  'Andris Biedrins',
#  'Andris Biedrins',
#  'Andris Biedrins',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Antawn Jamison',
#  'Ante Zizic',
#  'Ante Zizic',
#  'Ante Zizic',
#  'Anthony Davis',
#  'Anthony Davis',
#  'Anthony Davis',
#  'Anthony Davis',
#  'Anthony Davis',
#  'Anthony Davis',
#  'Anthony Davis',
#  'Anthony Davis',
#  'Anthony Davis',
#  'Anthony Randolph',
#  'Anthony Randolph',
#  'Anthony Randolph',
#  'Anthony Randolph',
#  'Anthony Randolph',
#  'Anthony Randolph',
#  'Anzejs Pasecniks',
#  'Anzejs Pasecniks',
#  'Arnett Moultrie',
#  'Arnett Moultrie',
#  'Austin Croshere',
#  'Austin Croshere',
#  'Austin Croshere',
#  'Austin Croshere',
#  'Austin Croshere',
#  'Austin Croshere',
#  'Austin Croshere',
#  'Austin Croshere',
#  'Austin Croshere',
#  'Austin Croshere',
#  'Austin Croshere',
#  'Austin Croshere',
#  'Austin Daye',
#  'Austin Daye',
#  'Austin Daye',
#  'Austin Daye',
#  'Austin Daye',
#  'Austin Daye',
#  'Bam Adebayo',
#  'Bam Adebayo',
#  'Bam Adebayo',
#  'Bam Adebayo',
#  'Ben Simmons',
#  'Ben Simmons',
#  'Ben Simmons',
#  'Ben Simmons',
#  'Bismack Biyombo',
#  'Bismack Biyombo',
#  'Bismack Biyombo',
#  'Bismack Biyombo',
#  'Bismack Biyombo',
#  'Bismack Biyombo',
#  'Bismack Biyombo',
#  'Bismack Biyombo',
#  'Blake Griffin',
#  'Blake Griffin',
#  'Blake Griffin',
#  'Blake Griffin',
#  'Blake Griffin',
#  'Blake Griffin',
#  'Blake Griffin',
#  'Blake Griffin',
#  'Blake Griffin',
#  'Blake Griffin',
#  'Blake Griffin',
#  'Bobby Portis',
#  'Bobby Portis',
#  'Bobby Portis',
#  'Bobby Portis',
#  'Bobby Portis',
#  'Bobby Portis',
#  'Bostjan Nachbar',
#  'Bostjan Nachbar',
#  'Bostjan Nachbar',
#  'Bostjan Nachbar',
#  'Bostjan Nachbar',
#  'Bostjan Nachbar',
#  'Brandan Wright',
#  'Brandan Wright',
#  'Brandan Wright',
#  'Brandan Wright',
#  'Brandan Wright',
#  'Brandan Wright',
#  'Brandan Wright',
#  'Brandan Wright',
#  'Brandan Wright',
#  'Brandan Wright',
#  'Brandon Ingram',
#  'Brandon Ingram',
#  'Brandon Ingram',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brendan Haywood',
#  'Brian Cook',
#  'Brian Cook',
#  'Brian Cook',
#  'Brian Cook',
#  'Brian Cook',
#  'Brian Cook',
#  'Brian Cook',
#  'Brian Cook',
#  'Brian Cook',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brian Skinner',
#  'Brice Johnson',
#  'Brice Johnson',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Brook Lopez',
#  'Bruno Caboclo',
#  'Bruno Caboclo',
#  'Bruno Caboclo',
#  'Bruno Caboclo',
#  'Bruno Caboclo',
#  'Bruno Caboclo',
#  'Bruno Caboclo',
#  'Byron Mullens',
#  'Byron Mullens',
#  'Byron Mullens',
#  'Byron Mullens',
#  'Byron Mullens',
#  'Cal Bowdler',
#  'Cal Bowdler',
#  'Cal Bowdler',
#  'Caleb Swanigan',
#  'Caleb Swanigan',
#  'Cedric Simmons',
#  'Cedric Simmons',
#  'Cedric Simmons',
#  'Channing Frye',
#  'Channing Frye',
#  'Channing Frye',
#  'Channing Frye',
#  'Channing Frye',
#  'Channing Frye',
#  'Channing Frye',
#  'Channing Frye',
#  'Channing Frye',
#  'Channing Frye',
#  'Channing Frye',
#  'Channing Frye',
#  'Channing Frye',
#  'Charlie Villanueva',
#  'Charlie Villanueva',
#  'Charlie Villanueva',
#  'Charlie Villanueva',
#  'Charlie Villanueva',
#  'Charlie Villanueva',
#  'Charlie Villanueva',
#  'Charlie Villanueva',
#  'Charlie Villanueva',
#  'Charlie Villanueva',
#  'Charlie Villanueva',
#  'Chris Anstey',
#  'Chris Anstey',
#  'Chris Anstey',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Bosh',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris Kaman',
#  'Chris McCullough',
#  'Chris McCullough',
#  'Chris McCullough',
#  'Chris Mihm',
#  'Chris Mihm',
#  'Chris Mihm',
#  'Chris Mihm',
#  'Chris Mihm',
#  'Chris Mihm',
#  'Chris Mihm',
#  'Chris Mihm',
#  'Chris Singleton',
#  'Chris Wilcox',
#  'Chris Wilcox',
#  'Chris Wilcox',
#  'Chris Wilcox',
#  'Chris Wilcox',
#  'Chris Wilcox',
#  'Chris Wilcox',
#  'Chris Wilcox',
#  'Chris Wilcox',
#  'Chris Wilcox',
#  'Chris Wilcox',
#  'Clint Capela',
#  'Clint Capela',
#  'Clint Capela',
#  'Clint Capela',
#  'Clint Capela',
#  'Clint Capela',
#  'Clint Capela',
#  'Cody Zeller',
#  'Cody Zeller',
#  'Cody Zeller',
#  'Cody Zeller',
#  'Cody Zeller',
#  'Cody Zeller',
#  'Cody Zeller',
#  'Cody Zeller',
#  'Cole Aldrich',
#  'Cole Aldrich',
#  'Cole Aldrich',
#  'Cole Aldrich',
#  'Cole Aldrich',
#  'Cole Aldrich',
#  'Cole Aldrich',
#  'Cole Aldrich',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Corey Brewer',
#  'Craig Brackins',
#  'Craig Brackins',
#  'Curtis Borchardt',
#  'Curtis Borchardt',
#  'D.J. Wilson',
#  'D.J. Wilson',
#  'D.J. Wilson',
#  'D.J. Wilson',
#  'DJ White',
#  'DJ White',
#  'DJ White',
#  'DJ White',
#  'DJ White',
#  'DJ White',
#  'Dalibor Bagaric',
#  'Dalibor Bagaric',
#  'Dalibor Bagaric',
#  'Damian Jones',
#  'Damian Jones',
#  'Damian Jones',
#  'Damian Jones',
#  'Damian Jones',
#  'Daniel Orton',
#  'Daniel Orton',
#  'Daniel Orton',
#  'Danilo Gallinari',
#  'Danilo Gallinari',
#  'Danilo Gallinari',
#  'Danilo Gallinari',
#  'Danilo Gallinari',
#  'Danilo Gallinari',
#  'Danilo Gallinari',
#  'Danilo Gallinari',
#  'Danilo Gallinari',
#  'Danilo Gallinari',
#  'Danilo Gallinari',
#  'Danilo Gallinari',
#  'Danny Granger',
#  'Danny Granger',
#  'Danny Granger',
#  'Danny Granger',
#  'Dario Saric',
#  'Dario Saric',
#  'Dario Saric',
#  'Dario Saric',
#  'Dario Saric',
#  'Darius Miles',
#  'Darius Miles',
#  'Darius Miles',
#  'Darius Miles',
#  'Darius Miles',
#  'Darius Miles',
#  'Darius Miles',
#  'Darko Milicic',
#  'Darko Milicic',
#  'Darko Milicic',
#  'Darko Milicic',
#  'Darko Milicic',
#  'Darko Milicic',
#  'Darko Milicic',
#  'Darko Milicic',
#  'Darko Milicic',
#  'Darko Milicic',
#  'Darrell Arthur',
#  'Darrell Arthur',
#  'Darrell Arthur',
#  'Darrell Arthur',
#  'Darrell Arthur',
#  'Darrell Arthur',
#  'Darrell Arthur',
#  'Darrell Arthur',
#  'Darrell Arthur',
#  'David Harrison',
#  'David Harrison',
#  'David Harrison',
#  'David Harrison',
#  'David Lee',
#  'David Lee',
#  'David Lee',
#  'David Lee',
#  'David Lee',
#  'David Lee',
#  'David Lee',
#  'David Lee',
#  'David Lee',
#  'David Lee',
#  'David Lee',
#  'David Lee',
#  'David West',
#  'David West',
#  'David West',
#  'David West',
#  'David West',
#  'David West',
#  'David West',
#  'David West',
#  'David West',
#  'David West',
#  'David West',
#  'David West',
#  'David West',
#  'David West',
#  'DeMarcus Cousins',
#  'DeMarcus Cousins',
#  'DeMarcus Cousins',
#  'DeMarcus Cousins',
#  'DeMarcus Cousins',
#  'DeMarcus Cousins',
#  'DeMarcus Cousins',
#  'DeMarcus Cousins',
#  'DeMarcus Cousins',
#  'DeMarcus Cousins',
#  'DeSagana Diop',
#  'DeSagana Diop',
#  'DeSagana Diop',
#  'DeSagana Diop',
#  'DeSagana Diop',
#  'DeSagana Diop',
#  'DeSagana Diop',
#  'DeSagana Diop',
#  'DeSagana Diop',
#  'DeSagana Diop',
#  'DeSagana Diop',
#  'DeSagana Diop',
#  'Deandre Ayton',
#  'Deandre Ayton',
#  'Deandre Ayton',
#  'Deni Avdija',
#  'DerMarr Johnson',
#  'DerMarr Johnson',
#  'DerMarr Johnson',
#  'DerMarr Johnson',
#  'DerMarr Johnson',
#  'DerMarr Johnson',
#  'DerMarr Johnson',
#  'Derrick Favors',
#  'Derrick Favors',
#  'Derrick Favors',
#  'Derrick Favors',
#  'Derrick Favors',
#  'Derrick Favors',
#  'Derrick Favors',
#  'Derrick Favors',
#  'Derrick Favors',
#  'Derrick Favors',
#  'Derrick Favors',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Dirk Nowitzki',
#  'Domantas Sabonis',
#  'Domantas Sabonis',
#  'Domantas Sabonis',
#  'Domantas Sabonis',
#  'Domantas Sabonis',
#  'Donatas Motiejunas',
#  'Donatas Motiejunas',
#  'Donatas Motiejunas',
#  'Donatas Motiejunas',
#  'Donatas Motiejunas',
#  'Donatas Motiejunas',
#  'Donte Greene',
#  'Donte Greene',
#  'Donte Greene',
#  'Donte Greene',
#  'Dorell Wright',
#  'Dorell Wright',
#  'Dorell Wright',
#  'Dorell Wright',
#  'Dorell Wright',
#  'Dorell Wright',
#  'Dorell Wright',
#  'Dorell Wright',
#  'Dragan Bender',
#  'Dragan Bender',
#  'Dragan Bender',
#  'Dragan Bender',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Drew Gooden',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dwight Howard',
#  'Dzanan Musa',
#  'Dzanan Musa',
#  'Earl Clark',
#  'Earl Clark',
#  'Earl Clark',
#  'Earl Clark',
#  'Earl Clark',
#  'Earl Clark',
#  'Ed Davis',
#  'Ed Davis',
#  'Ed Davis',
#  'Ed Davis',
#  'Ed Davis',
#  'Ed Davis',
#  'Ed Davis',
#  'Ed Davis',
#  'Ed Davis',
#  'Ed Davis',
#  'Ed Davis',
#  'Eddie Griffin',
#  'Eddie Griffin',
#  'Eddie Griffin',
#  'Eddie Griffin',
#  'Eddie Griffin',
#  'Eddy Curry',
#  'Eddy Curry',
#  'Eddy Curry',
#  'Eddy Curry',
#  'Eddy Curry',
#  'Eddy Curry',
#  'Eddy Curry',
#  'Eddy Curry',
#  'Eddy Curry',
#  'Eddy Curry',
#  'Eddy Curry',
#  'Ekpe Udoh',
#  'Ekpe Udoh',
#  'Ekpe Udoh',
#  'Ekpe Udoh',
#  'Ekpe Udoh',
#  'Ekpe Udoh',
#  'Ekpe Udoh',
#  'Elton Brand',
#  'Elton Brand',
#  'Elton Brand',
#  'Elton Brand',
#  'Elton Brand',
#  'Elton Brand',
#  'Elton Brand',
#  'Elton Brand',
#  'Emeka Okafor',
#  'Emeka Okafor',
#  'Emeka Okafor',
#  'Emeka Okafor',
#  'Emeka Okafor',
#  'Emeka Okafor',
#  'Emeka Okafor',
#  'Emeka Okafor',
#  'Emeka Okafor',
#  'Emeka Okafor',
#  'Enes Kanter',
#  'Enes Kanter',
#  'Enes Kanter',
#  'Enes Kanter',
#  'Enes Kanter',
#  'Enes Kanter',
#  'Enes Kanter',
#  'Enes Kanter',
#  'Enes Kanter',
#  'Enes Kanter',
#  'Etan Thomas',
#  'Etan Thomas',
#  'Etan Thomas',
#  'Etan Thomas',
#  'Etan Thomas',
#  'Etan Thomas',
#  'Etan Thomas',
#  'Etan Thomas',
#  'Etan Thomas',
#  'Fab Melo',
#  'Festus Ezeli',
#  'Festus Ezeli',
#  'Festus Ezeli',
#  'Frank Kaminsky',
#  'Frank Kaminsky',
#  'Frank Kaminsky',
#  'Frank Kaminsky',
#  'Frank Kaminsky',
#  'Frank Kaminsky',
#  'Georgios Papagiannis',
#  'Georgios Papagiannis',
#  'Giannis Antetokounmpo',
#  'Giannis Antetokounmpo',
#  'Giannis Antetokounmpo',
#  'Giannis Antetokounmpo',
#  'Giannis Antetokounmpo',
#  'Giannis Antetokounmpo',
#  'Giannis Antetokounmpo',
#  'Giannis Antetokounmpo',
#  'Goga Bitadze',
#  'Goga Bitadze',
#  'Gorgui Dieng',
#  'Gorgui Dieng',
#  'Gorgui Dieng',
#  'Gorgui Dieng',
#  'Gorgui Dieng',
#  'Gorgui Dieng',
#  'Gorgui Dieng',
#  'Gorgui Dieng',
#  'Greg Monroe',
#  'Greg Monroe',
#  'Greg Monroe',
#  'Greg Monroe',
#  'Greg Monroe',
#  'Greg Monroe',
#  'Greg Monroe',
#  'Greg Monroe',
#  'Greg Monroe',
#  'Greg Oden',
#  'Greg Oden',
#  'Greg Oden',
#  'Hakim Warrick',
#  'Hakim Warrick',
#  'Hakim Warrick',
#  'Hakim Warrick',
#  'Hakim Warrick',
#  'Hakim Warrick',
#  'Hakim Warrick',
#  'Hakim Warrick',
#  'Harry Giles III',
#  'Harry Giles III',
#  'Harry Giles III',
#  'Hasheem Thabeet',
#  'Hasheem Thabeet',
#  'Hasheem Thabeet',
#  'Hasheem Thabeet',
#  'Hasheem Thabeet',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Hedo Turkoglu',
#  'Henry Ellenson',
#  'Henry Ellenson',
#  'Henry Ellenson',
#  'Henry Ellenson',
#  'Henry Ellenson',
#  'Hilton Armstrong',
#  'Hilton Armstrong',
#  'Hilton Armstrong',
#  'Hilton Armstrong',
#  'Hilton Armstrong',
#  'Hilton Armstrong',
#  'Ian Mahinmi',
#  'Ian Mahinmi',
#  'Ian Mahinmi',
#  'Ian Mahinmi',
#  'Ian Mahinmi',
#  'Ian Mahinmi',
#  'Ian Mahinmi',
#  'Ian Mahinmi',
#  'Ian Mahinmi',
#  'Ian Mahinmi',
#  'Ian Mahinmi',
#  'Ian Mahinmi',
#  'Ike Diogu',
#  'Ike Diogu',
#  'Ike Diogu',
#  'JJ Hickson',
#  'JJ Hickson',
#  'JJ Hickson',
#  'JJ Hickson',
#  'JJ Hickson',
#  'JJ Hickson',
#  'JJ Hickson',
#  'JJ Hickson',
#  'JaJuan Johnson',
#  'JaVale McGee',
#  'JaVale McGee',
#  'JaVale McGee',
#  'JaVale McGee',
#  'JaVale McGee',
#  'JaVale McGee',
#  'JaVale McGee',
#  'JaVale McGee',
#  'JaVale McGee',
#  'JaVale McGee',
#  'JaVale McGee',
#  'JaVale McGee',
#  'JaVale McGee',
#  'Jaden McDaniels',
#  'Jahlil Okafor',
#  'Jahlil Okafor',
#  'Jahlil Okafor',
#  'Jahlil Okafor',
#  'Jahlil Okafor',
#  'Jahlil Okafor',
#  'Jake Tsakalidis',
#  'Jake Tsakalidis',
#  'Jake Tsakalidis',
#  'Jake Tsakalidis',
#  'Jake Tsakalidis',
#  'Jake Tsakalidis',
#  'Jake Tsakalidis',
#  'Jakob Poeltl',
#  'Jakob Poeltl',
#  'Jakob Poeltl',
#  'Jakob Poeltl',
#  'Jakob Poeltl',
#  'Jalen Smith',
#  'Jamaal Magloire',
#  'Jamaal Magloire',
#  'Jamaal Magloire',
#  'Jamaal Magloire',
#  'Jamaal Magloire',
#  'Jamaal Magloire',
#  'Jamaal Magloire',
#  'Jamaal Magloire',
#  'Jamaal Magloire',
#  'Jamaal Magloire',
#  'Jamaal Magloire',
#  'Jamaal Magloire',
#  'James Johnson',
#  'James Johnson',
#  'James Johnson',
#  'James Johnson',
#  'James Johnson',
#  'James Johnson',
#  'James Johnson',
#  'James Johnson',
#  'James Wiseman',
#  'Jan Vesely',
#  'Jan Vesely',
#  'Jan Vesely',
#  'Jared Jeffries',
#  'Jared Jeffries',
#  'Jared Jeffries',
#  'Jared Jeffries',
#  'Jared Jeffries',
#  'Jared Jeffries',
#  'Jared Jeffries',
#  'Jared Jeffries',
#  'Jared Jeffries',
#  'Jared Jeffries',
#  'Jared Jeffries',
#  'Jared Sullinger',
#  'Jared Sullinger',
#  'Jared Sullinger',
#  'Jared Sullinger',
#  'Jared Sullinger',
#  'Jarell Martin',
#  'Jarell Martin',
#  'Jarell Martin',
#  'Jarell Martin',
#  'Jaren Jackson Jr.',
#  'Jaren Jackson Jr.',
#  'Jaren Jackson Jr.',
#  'Jarrett Allen',
#  'Jarrett Allen',
#  'Jarrett Allen',
#  'Jarrett Allen',
#  'Jason Collier',
#  'Jason Collier',
#  'Jason Collier',
#  'Jason Collier',
#  'Jason Collier',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Collins',
#  'Jason Smith',
#  'Jason Smith',
#  'Jason Smith',
#  'Jason Smith',
#  'Jason Smith',
#  'Jason Smith',
#  'Jason Smith',
#  'Jason Smith',
#  'Jason Smith',
#  'Jason Smith',
#  'Jason Smith',
#  'Jason Thompson',
#  'Jason Thompson',
#  'Jason Thompson',
#  'Jason Thompson',
#  'Jason Thompson',
#  'Jason Thompson',
#  'Jason Thompson',
#  'Jason Thompson',
#  'Jaxson Hayes',
#  'Jaxson Hayes',
#  'Jeff Foster',
#  ...]

# %%
#Get Unique Players
df2.sort_values(["player_name", "season"])
df2.player_name.unique()
df4 = df2.drop_duplicates(subset = "player_name")
df4
# Out:
#               player_name team_abbreviation   age  player_height  \
# 553       Austin Croshere               IND  23.0           81.0
# 582          Adonal Foyle               GSW  23.0           82.0
# 657          Chris Anstey               DAL  23.0           84.0
# 687          Scot Pollard               DET  23.0           83.0
# 751            Tim Duncan               SAS  22.0           84.0
# ...                   ...               ...   ...            ...
# 11293         Jalen Smith               PHX  21.0           82.0
# 11340  Aleksej Pokusevski               OKC  19.0           84.0
# 11388         Deni Avdija               WAS  20.0           81.0
# 11470          Obi Toppin               NYK  23.0           81.0
# 11517      Udoka Azubuike               UTA  21.0           82.0
#
#        player_weight      college                   country draft_year  \
# 553            235.0   Providence                       USA       1997
# 582            250.0      Colgate  St. Vincent & Grenadines       1997
# 657            249.0         None                       USA       1997
# 687            265.0       Kansas                       USA       1997
# 751            248.0  Wake Forest         US Virgin Islands       1997
# ...              ...          ...                       ...        ...
# 11293          215.0     Maryland                       USA       2020
# 11340          190.0         None                    Serbia       2020
# 11388          210.0         None                    Israel       2020
# 11470          220.0       Dayton                       USA       2020
# 11517          280.0       Kansas                   Nigeria       2020
#
#       draft_round draft_number  ...   pts   reb  ast  net_rating  oreb_pct  \
# 553             1           12  ...   2.9   1.7  0.3        -3.1     0.047
# 582             1            8  ...   3.0   3.3  0.3       -11.8     0.112
# 657             1           18  ...   5.9   3.8  0.9        -9.8     0.082
# 687             1           19  ...   2.7   2.2  0.3         0.8     0.133
# 751             1            1  ...  21.1  11.9  2.7         8.0     0.108
# ...           ...          ...  ...   ...   ...  ...         ...       ...
# 11293           1           10  ...   2.0   1.4  0.1        -4.4     0.044
# 11340           1           17  ...   8.2   4.7  2.2       -16.7     0.025
# 11388           1            9  ...   6.3   4.9  1.2        -2.1     0.017
# 11470           1            8  ...   4.1   2.2  0.5         2.7     0.037
# 11517           1           27  ...   1.1   0.9  0.0       -54.5     0.063
#
#        dreb_pct  usg_pct  ts_pct  ast_pct   season
# 553       0.169    0.194   0.412    0.052  1997-98
# 582       0.182    0.162   0.418    0.037  1997-98
# 657       0.174    0.201   0.455    0.094  1997-98
# 687       0.150    0.136   0.555    0.050  1997-98
# 751       0.238    0.262   0.577    0.131  1997-98
# ...         ...      ...     ...      ...      ...
# 11293     0.174    0.161   0.499    0.037  2020-21
# 11340     0.155    0.197   0.430    0.133  2020-21
# 11388     0.181    0.118   0.515    0.064  2020-21
# 11470     0.155    0.157   0.574    0.065  2020-21
# 11517     0.150    0.119   0.597    0.000  2020-21
#
# [307 rows x 21 columns]

# %%
import matplotlib.pyplot as plt

# %%
vis1 = sns.distplot(df4.draft_year, bins = 15)

# %%
#First Round Big Men In NBA each year from 97 season on 
#bm1 = plt.hist(data = df4, x ="draft_year", bins = 15 )
bp = sns.barplot(data = df4, x = "draft_year", y = )
plt.xticks(rotation = 45)
plt.show()

# %%
#Player Weight Per Year
sns.boxplot(data = df4, x="draft_year", y = "player_weight" )
plt.xticks(rotation = 45)
plt.show()

# %%
#Offensive Rebound Percentage
vis2 = sns.lineplot(data = df2, x= "season", y = "oreb_pct")
plt.xticks(rotation = 45)
plt.show()

# %%
#Usage Percentage
vis2 = sns.lineplot(data = df2, x= "season", y = "usg_pct")
plt.xticks(rotation = 45)
plt.show()

# %%
#Usage Percentage
vis2 = sns.lineplot(data = df2, x= "season", y = "ts_pct")
plt.xticks(rotation = 45)
plt.show()

# %%
df3 = df

# %%
df3[H]
df3 = df3[df3.draft_year.isin(D)]
df3 = df3[H]
df3
# Out:
#              player_name team_abbreviation   age  player_height  \
# 514         Jason Lawson               ORL  23.0           83.0
# 553      Austin Croshere               IND  23.0           81.0
# 578     Jerald Honeycutt               MIL  23.0           81.0
# 582         Adonal Foyle               GSW  23.0           82.0
# 632       Chris Crawford               ATL  23.0           81.0
# ...                  ...               ...   ...            ...
# 11686    Markieff Morris               LAL  31.0           81.0
# 11688     Marques Bolden               CLE  23.0           82.0
# 11689    Marquese Chriss               GSW  23.0           81.0
# 11690  Marvin Bagley III               SAC  22.0           83.0
# 11692      Mason Plumlee               DET  31.0           83.0
#
#        player_weight     college                   country draft_year  \
# 514            240.0   Villanova                       USA       1997
# 553            235.0  Providence                       USA       1997
# 578            254.0      Tulane                       USA       1997
# 582            250.0     Colgate  St. Vincent & Grenadines       1997
# 632            235.0   Marquette                       USA       1997
# ...              ...         ...                       ...        ...
# 11686          245.0      Kansas                       USA       2011
# 11688          249.0        Duke                       USA       2019
# 11689          240.0  Washington                       USA       2016
# 11690          235.0        Duke                       USA       2018
# 11692          254.0        Duke                       USA       2013
#
#       draft_round draft_number  ...   pts  reb  ast  net_rating  oreb_pct  \
# 514             2           41  ...   1.5  1.6  0.3         7.4     0.104
# 553             1           12  ...   2.9  1.7  0.3        -3.1     0.047
# 578             2           38  ...   6.4  2.4  0.9         2.1     0.058
# 582             1            8  ...   3.0  3.3  0.3       -11.8     0.112
# 632             2           50  ...   3.8  1.0  0.2        -7.1     0.081
# ...           ...          ...  ...   ...  ...  ...         ...       ...
# 11686           1           13  ...   6.7  4.4  1.2         0.8     0.040
# 11688   Undrafted    Undrafted  ...   1.2  1.0  0.0        12.3     0.083
# 11689           1            8  ...   6.5  6.5  1.0       -40.3     0.075
# 11690           1            2  ...  14.1  7.4  1.0        -3.7     0.092
# 11692           1           22  ...  10.4  9.3  3.6        -4.9     0.095
#
#        dreb_pct  usg_pct  ts_pct  ast_pct   season
# 514       0.345    0.111   0.670    0.083  1997-98
# 553       0.169    0.194   0.412    0.052  1997-98
# 578       0.149    0.245   0.497    0.111  1997-98
# 582       0.182    0.162   0.418    0.037  1997-98
# 632       0.084    0.252   0.536    0.062  1997-98
# ...         ...      ...     ...      ...      ...
# 11686     0.176    0.160   0.509    0.088  2020-21
# 11688     0.088    0.136   0.537    0.000  2020-21
# 11689     0.385    0.250   0.412    0.200  2020-21
# 11690     0.188    0.229   0.554    0.057  2020-21
# 11692     0.264    0.163   0.638    0.205  2020-21
#
# [3028 rows x 21 columns]

# %%
#Usage Percentage
TS = sns.lineplot(data = df3, x= "season", y = "ts_pct")
plt.xticks(rotation = 45)
plt.show()

# %%
#Usage Percentage
Usg = sns.lineplot(data = df3, x= "season", y = "usg_pct")
plt.xticks(rotation = 45)
plt.show()

# %%
#Offensive Rebound Percentage
Oreb = sns.lineplot(data = df3, x= "season", y = "oreb_pct")
plt.xticks(rotation = 45)
plt.show()

# %%
sns.set_style("dark", {"axes.facecolor" : "lightgray"})
f, ax = plt.subplots(1,1)
f, axes = plt.subplots(2,2, figsize=(15,15))
#Charts
ax.hist(data = df4, x ="draft_year", bins = 15, color = "mediumseagreen")
TS = sns.lineplot(data = df3, x= "season", y = "ts_pct", ax = axes[0,0], color = "mediumseagreen")
Oreb = sns.lineplot(data = df3, x= "season", y = "oreb_pct", ax = axes[0,1],color = "mediumseagreen")
Usg = sns.lineplot(data = df3, x= "season", y = "usg_pct", ax = axes[1,0],color = "mediumseagreen")
PW = sns.boxplot(data = df4, x="draft_year", y = "player_weight", ax = axes[1,1], color = "mediumseagreen",)

#Axis
ax.tick_params(axis = 'x', rotation = 90)
axes[0,0].tick_params(axis='x', rotation=90)
axes[0,1].tick_params(axis='x', rotation=90)
axes[1,0].tick_params(axis='x', rotation=90)
axes[1,1].tick_params(axis='x', rotation=90)
ax.set(xlabel='Season', ylabel = '# of First Round Big Men')
axes[0,0].set(xlabel='Season', ylabel = 'True Shooting %')
axes[0,1].set(xlabel='Season', ylabel = 'Offensive Rebound %')
axes[1,0].set(xlabel='Season', ylabel = 'Usage %')
axes[1,1].set(xlabel='Draft Year', ylabel = 'Player Weight')

plt.show()
